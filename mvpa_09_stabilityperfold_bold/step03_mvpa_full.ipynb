# %% [markdown]
#  # MVPA Per Subject

# %%
import numpy as np
import nibabel as nb
import os

# %%
# define paths
root_dir = '/Volumes/T7/BIDS-BRAINPLAYBACK-TASK2'
fmriprep_dir = os.path.join(root_dir, 'derivatives', 'fmriprep23')
dataset_dir  = os.path.join(root_dir, 'derivatives', 'mvpa_09_stabilityperfold_bold', 'features_full')

# %%
# list datasets and concatenate

# find all *_dataset.nii.gz files in dataset_dir
dataset_files_fold = {}
dataset_files_fold['0'] = [os.path.join(dataset_dir, f) for f in os.listdir(dataset_dir) if f.endswith('fold-0_features.npy') & f.startswith('sub-')]
dataset_files_fold['1'] = [os.path.join(dataset_dir, f) for f in os.listdir(dataset_dir) if f.endswith('fold-1_features.npy') & f.startswith('sub-')]
dataset_files_fold['2'] = [os.path.join(dataset_dir, f) for f in os.listdir(dataset_dir) if f.endswith('fold-2_features.npy') & f.startswith('sub-')]
dataset_files_fold['3'] = [os.path.join(dataset_dir, f) for f in os.listdir(dataset_dir) if f.endswith('fold-3_features.npy') & f.startswith('sub-')]

# sort all files
for fold in dataset_files_fold.keys():
    dataset_files_fold[fold].sort()

# find all *_trial_types.txt files in dataset_dir
labels_files_fold = {}
labels_files_fold['0'] = [os.path.join(dataset_dir, f) for f in os.listdir(dataset_dir) if f.endswith('fold-0_labels.npy') & f.startswith('sub-')]
labels_files_fold['1'] = [os.path.join(dataset_dir, f) for f in os.listdir(dataset_dir) if f.endswith('fold-1_labels.npy') & f.startswith('sub-')]
labels_files_fold['2'] = [os.path.join(dataset_dir, f) for f in os.listdir(dataset_dir) if f.endswith('fold-2_labels.npy') & f.startswith('sub-')]
labels_files_fold['3'] = [os.path.join(dataset_dir, f) for f in os.listdir(dataset_dir) if f.endswith('fold-3_labels.npy') & f.startswith('sub-')]

# sort all files
for fold in labels_files_fold.keys():
    labels_files_fold[fold].sort()

# %%
# get number of subjects
n_runs_per_sub = 4
n_folds = int(n_runs_per_sub)
n_subjects = len(dataset_files_fold['0']) / n_runs_per_sub
print('Number of subjects found: %f' % n_subjects)
# Out:
# Number of subjects found: 19.000000

# %%
# estimate expected number of rows
# 19 subjects, 8 noise and 9 x 2 music for each of the 4 runs

n_music_trials = 9*2
n_music_splits = 4

n_rows_estimate_per_run = n_music_trials*n_music_splits
n_rows_estimate_per_sub = n_runs_per_sub * n_rows_estimate_per_run
n_rows_estimate = n_subjects * n_rows_estimate_per_sub
print(f'Estimated number of rows: {n_rows_estimate}')
# Out:
# Estimated number of rows: 5472.0

# %%
# generate an array of chunk labels
chunks = np.repeat(np.arange(1,n_runs_per_sub+1), n_rows_estimate_per_run)
chunks.shape
# Out:
# (288,)

# %%
from sklearn.metrics import balanced_accuracy_score
import numpy as np
from sklearn.svm import LinearSVC
from concurrent.futures import ThreadPoolExecutor
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import GridSearchCV

n_classes = 9
class_names = ['JoyfulActivation','Nostalgia','Peacefulness','Power','Sadness','Tenderness','Tension','Transcendence','Wonder']
#n_folds = int(n_runs_per_sub)
n_subjects = int(n_subjects)
acc_array = np.zeros((n_subjects,n_folds))
acc_bal_array = np.zeros((n_subjects,n_folds))
confusion_matrix_array = np.zeros((n_subjects,n_classes,n_classes,n_folds))
acc_train_cv_array = np.zeros((n_subjects,n_folds))
c_train_cv_array = np.zeros((n_subjects,n_folds))

def process_fold(ss, chunks):
    print(f'subject {ss+1}/{n_subjects}...')

    start_idx = (ss+1-1)*n_runs_per_sub
    end_idx = n_runs_per_sub*(ss+1)
    print(f'Selection from {start_idx} to {end_idx}')


    c_train_cv = np.zeros(n_folds)
    acc_train_cv = np.zeros(n_folds)
    acc = np.zeros(n_folds)
    acc_bal = np.zeros(n_folds)
    cm = np.zeros((n_classes,n_classes,n_folds))

    if ss == 17: # subject 18 run 2 is missing the power condition
        # remove eight 2's from chunks
        chunks = np.delete(chunks, np.where(chunks == 2)[0][0:8])

    for ff in range(n_folds):
        print(f'fold {ff+1}/{n_folds}...')

        # Load the data for this specific fold
        samples = np.concatenate([np.load(f) for f in dataset_files_fold[str(ff)][start_idx:end_idx]], axis=0)
        labels = np.concatenate([np.load(f, allow_pickle=True) for f in labels_files_fold[str(ff)][start_idx:end_idx]], axis=0)

        # split the data into training and test set
        train_mask = chunks != ff+1
        test_mask = chunks == ff+1

        X_train = samples[train_mask, :]
        y_train = labels[train_mask]
        X_test = samples[test_mask, :]
        y_test = labels[test_mask]

        # GridSearch + Training
        parameters = {'C':range(1,21)}

        svc = LinearSVC(multi_class="ovr", max_iter=5000, class_weight='balanced', dual='auto')

        clf = GridSearchCV(svc, parameters,
                           return_train_score=True, cv=3, n_jobs=2)

        clf.fit(X_train, y_train)

        # Store the best parameters
        c_train_cv[ff] = clf.best_params_['C']
        acc_train_cv[ff] = clf.best_score_

        # Testing
        y_pred = clf.best_estimator_.predict(X_test)

        # Compute the prediction accuracy for the different labels
        acc[ff] = (y_pred == y_test).mean()
        acc_bal[ff] = balanced_accuracy_score(y_test, y_pred)

        # confusion matrix
        cm[...,ff] = confusion_matrix(y_test, y_pred, normalize='true')

    return ss, acc, acc_bal, cm, acc_train_cv, c_train_cv

# execute the process_fold function with the chunks argument
with ThreadPoolExecutor(max_workers=4) as executor:
    results = list(executor.map(process_fold, range(int(n_subjects)), [chunks]*int(n_subjects)))

# Update the accuracy arrays with the results
for ss, acc, acc_bal, cm, acc_train_cv, c_train_cv in results:
    acc_array[ss,:] = acc
    acc_bal_array[ss,:] = acc_bal
    confusion_matrix_array[ss,...] = cm
    acc_train_cv_array[ss,:] = acc_train_cv
    c_train_cv_array[ss,:] = c_train_cv
# Out:
# subject 1/19...
# Selection from 0 to 4
# fold 1/4...
# subject 2/19...
# Selection from 4 to 8
# fold 1/4...
# subject 3/19...
# Selection from 8 to 12
# fold 1/4...
# subject 4/19...
# Selection from 12 to 16
# fold 1/4...
# fold 2/4...
# fold 2/4...
# fold 2/4...
# fold 2/4...
# fold 3/4...
# fold 3/4...
# fold 3/4...
# fold 3/4...
# fold 4/4...
# fold 4/4...
# fold 4/4...
# fold 4/4...
# subject 5/19...
# Selection from 16 to 20
# fold 1/4...
# subject 6/19...
# Selection from 20 to 24
# fold 1/4...
# subject 7/19...
# Selection from 24 to 28
# fold 1/4...
# subject 8/19...
# Selection from 28 to 32
# fold 1/4...
# fold 2/4...
# fold 2/4...
# fold 2/4...
# fold 2/4...
# fold 3/4...
# fold 3/4...
# fold 3/4...
# fold 3/4...
# fold 4/4...
# fold 4/4...
# fold 4/4...
# fold 4/4...
# subject 9/19...
# Selection from 32 to 36
# fold 1/4...
# subject 10/19...
# Selection from 36 to 40
# fold 1/4...
# subject 11/19...
# Selection from 40 to 44
# fold 1/4...
# subject 12/19...
# Selection from 44 to 48
# fold 1/4...
# fold 2/4...
# fold 2/4...
# fold 2/4...
# fold 2/4...
# fold 3/4...
# fold 3/4...
# fold 3/4...
# fold 3/4...
# fold 4/4...
# fold 4/4...
# fold 4/4...
# fold 4/4...
# subject 13/19...
# Selection from 48 to 52
# fold 1/4...
# subject 14/19...
# Selection from 52 to 56
# fold 1/4...
# subject 15/19...
# Selection from 56 to 60
# fold 1/4...
# subject 16/19...
# Selection from 60 to 64
# fold 1/4...
# fold 2/4...
# fold 2/4...
# fold 2/4...
# fold 2/4...
# fold 3/4...
# fold 3/4...
# fold 3/4...
# fold 3/4...
# fold 4/4...
# fold 4/4...
# fold 4/4...
# fold 4/4...
# subject 17/19...
# Selection from 64 to 68
# fold 1/4...
# subject 18/19...
# Selection from 68 to 72
# fold 1/4...
# subject 19/19...
# Selection from 72 to 76
# fold 1/4...
# fold 2/4...
# fold 2/4...
# fold 2/4...
# fold 3/4...
# /opt/anaconda3/envs/brainplayback_task02/lib/python3.11/site-packages/sklearn/metrics/_classification.py:2458: UserWarning: y_pred contains classes not in y_true
#   warnings.warn("y_pred contains classes not in y_true")
# fold 3/4...
# fold 3/4...
# fold 4/4...
# fold 4/4...
# fold 4/4...

# %%
m_s = np.mean(np.mean(acc_array,1))*100
s_s = np.std(np.mean(acc_array,1))*100

m_b_s = np.mean(np.mean(acc_bal_array,1))*100
s_b_s = np.std(np.mean(acc_bal_array,1))*100

m_t = np.mean(np.mean(acc_train_cv_array,1))*100 # training accuracy from grid search
s_t = np.std(np.mean(acc_train_cv_array,1))*100

c_t = np.mean(np.mean(c_train_cv_array,1)) # training C from grid search
s_c = np.std(np.mean(c_train_cv_array,1))

# %%
print(f"Mean test accuracy across subs: {m_s:0.1f}% \u00B1 {s_s:0.1f}%")
print(f"Mean test balanced accuracy across subs: {m_b_s:0.1f}% \u00B1 {s_b_s:0.1f}%")
print(f"Mean grid CV training accuracy across subs: {m_t:0.1f}% \u00B1 {s_t:0.1f}%")
print(f"Mean grid CV training C parameter across subs: {c_t:0.1f} \u00B1 {s_c:0.1f}")
# Out:
# Mean test accuracy across subs: 17.6% ± 4.1%
# Mean test balanced accuracy across subs: 17.6% ± 4.1%
# Mean grid CV training accuracy across subs: 48.1% ± 4.1%
# Mean grid CV training C parameter across subs: 1.2 ± 0.5

# %%
M = np.mean(np.mean(confusion_matrix_array,3),0)*100

M_annot = []

for i in range(M.shape[0]):
    for j in range(M.shape[1]):
        aux = f'{M[i, j]:0.1f}%'
        M_annot.append(aux)

M_annot_plot =  np.array(M_annot).reshape(M.shape)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 6))
sns.heatmap(M, annot=M_annot_plot, fmt = '', cmap='Blues',
            vmin=0, vmax=100,             
            xticklabels=class_names, yticklabels=class_names, 
            annot_kws={"size": 8},
            cbar_kws={'label': 'Percentage of true labels'})
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title(f'Overall balanced accuracy = {acc_array.mean()*100:0.1f}% \u00B1 {acc_array.std()*100:0.1f}%')
plt.show()
