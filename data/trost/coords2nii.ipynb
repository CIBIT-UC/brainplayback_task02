# %%
#%% Import libraries
import os
import pandas as pd

# %%
#%% Load the coordinates
coords = pd.read_csv("clusters.csv")
coords
# Out:
#                                         Region  BA Cluster_size  z-value   X  \
# 0             Retrosplenial_cingulate_cortex_R  29           29     4.69  12
# 1             Retrosplenial_cingulate_cortex_L  29           25     4.23 -12
# 2         Ventral_striatum_nucleus_accumbens_R   *           60     4.35  12
# 3         Ventral_striatum_nucleus_accumbens_L   *           14     3.51 -12
# 4                           Ventral_pallidum_R   *            3     3.23  27
# 5                                Subgenual_ACC  25           88     3.86   0
# 6                              Rostral_ACC_1_R  24            *     3.82   3
# 7                              Rostral_ACC_2_R  32            *     3.36   3
# 8                                Hippocampus_R  28           69     4.17  27
# 9                            Parahippocampus_R  34            *     3.69  39
# 10                                       PHG_L  36            8     3.62 -27
# ...

# %%
#%% Iterate
maxV = coords.shape[0]
for i in range(maxV):

    x = coords.iloc[i, 7]
    y = coords.iloc[i, 8]
    z = coords.iloc[i, 9]
    name = coords.iloc[i, 0]

    os.system(f"fslmaths $FSLDIR/data/standard/MNI152_T1_2mm.nii.gz -mul 0 -add 1 -roi {x} 1 {y} 1 {z} 1 0 1 spheres/{name}_roi.nii.gz -odt float") 

    os.system(f"fslmaths spheres/{name}_roi.nii.gz -kernel sphere 6 -fmean spheres/{name}_roi.nii.gz -odt float")

    os.system(f"fslmaths spheres/{name}_roi.nii.gz -bin -mul {i+1} spheres/{name}_roi.nii.gz ")

# %%
# check for repeated names in the cluster names
# find unique names
unique_number = len(coords["Region"].unique())
if unique_number != maxV:
    print("Warning: There are repeated names in the cluster names")
else:
    print("all good, all names are unique")
# Out:
# all good, all names are unique

# %%
# create spheres path list
spheres_list = []
for ii in range(maxV):
    spheres_list.append(f"spheres/{coords.iloc[ii,0]}_roi.nii.gz")
spheres_list
# Out:
# ['spheres/Retrosplenial_cingulate_cortex_R_roi.nii.gz',
#  'spheres/Retrosplenial_cingulate_cortex_L_roi.nii.gz',
#  'spheres/Ventral_striatum_nucleus_accumbens_R_roi.nii.gz',
#  'spheres/Ventral_striatum_nucleus_accumbens_L_roi.nii.gz',
#  'spheres/Ventral_pallidum_R_roi.nii.gz',
#  'spheres/Subgenual_ACC_roi.nii.gz',
#  'spheres/Rostral_ACC_1_R_roi.nii.gz',
#  'spheres/Rostral_ACC_2_R_roi.nii.gz',
#  'spheres/Hippocampus_R_roi.nii.gz',
#  'spheres/Parahippocampus_R_roi.nii.gz',
#  'spheres/PHG_L_roi.nii.gz',
#  'spheres/Middle_temporal_gyrus_1_R_roi.nii.gz',
#  'spheres/Middle_temporal_gyrus_2_R_roi.nii.gz',
#  'spheres/Anterior_insula_L_roi.nii.gz',
#  'spheres/Inferior_frontal_gyrus_pars_triangularis_R_roi.nii.gz',
#  'spheres/Somatosensory_cortex_R_roi.nii.gz',
#  'spheres/Somatosensory_association_cortex_R_roi.nii.gz',
#  'spheres/Motor_cortex_R_roi.nii.gz',
#  'spheres/Occipital_visual_cortex_L_roi.nii.gz',
#  'spheres/Cerebellum_L_roi.nii.gz']

# %%
# %% sphere_list to single string split with spaces
spheres_str = " -add ".join(spheres_list)
spheres_str
# Out:
# 'spheres/Retrosplenial_cingulate_cortex_R_roi.nii.gz -add spheres/Retrosplenial_cingulate_cortex_L_roi.nii.gz -add spheres/Ventral_striatum_nucleus_accumbens_R_roi.nii.gz -add spheres/Ventral_striatum_nucleus_accumbens_L_roi.nii.gz -add spheres/Ventral_pallidum_R_roi.nii.gz -add spheres/Subgenual_ACC_roi.nii.gz -add spheres/Rostral_ACC_1_R_roi.nii.gz -add spheres/Rostral_ACC_2_R_roi.nii.gz -add spheres/Hippocampus_R_roi.nii.gz -add spheres/Parahippocampus_R_roi.nii.gz -add spheres/PHG_L_roi.nii.gz -add spheres/Middle_temporal_gyrus_1_R_roi.nii.gz -add spheres/Middle_temporal_gyrus_2_R_roi.nii.gz -add spheres/Anterior_insula_L_roi.nii.gz -add spheres/Inferior_frontal_gyrus_pars_triangularis_R_roi.nii.gz -add spheres/Somatosensory_cortex_R_roi.nii.gz -add spheres/Somatosensory_association_cortex_R_roi.nii.gz -add spheres/Motor_cortex_R_roi.nii.gz -add spheres/Occipital_visual_cortex_L_roi.nii.gz -add spheres/Cerebellum_L_roi.nii.gz'

# %%
# %% combine all the spheres
os.system(f"fslmaths {spheres_str} spheres/trost_spheres_atlas.nii.gz")
# Out:
# 0

# %%
# remove all overlaps
os.system(f"fslmaths spheres/trost_spheres_atlas.nii.gz -uthr {maxV} spheres/trost_spheres_atlas.nii.gz")
# Out:
# 0

# %%
# export region names as txt file
region_names = coords.iloc[:, 0]
region_names.to_csv("spheres/trost_spheres_atlas.txt", index=False, header=False)
